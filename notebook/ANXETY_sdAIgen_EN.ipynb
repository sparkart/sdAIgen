# %%
# @title Setup Environment.
from pathlib import Path
import os

lang, branch = 'en', 'main'
scripts_dir = Path.home() / 'ANXETY' / 'scripts'
output = scripts_dir / 'setup.py'

os.makedirs(output.parent, exist_ok=True)
# !curl -sLo {output} https://raw.githubusercontent.com/sparkart/sdAIgen/{branch}/scripts/setup.py

# %run $output --lang=$lang --branch=$branch

# %% [markdown]
# ---
# ## 1. Widgets 🔽

# %%
# Model selection, vae, control-net and more.
# %run $scripts_dir/$lang/widgets-{lang}.py

# %% [markdown]
# ## 2. Downloading 🔽

# %%
# Downloading libraries, repos, models and more.
# %run $scripts_dir/$lang/downloading-{lang}.py

# %% [markdown]
# ## 3. Start 🔽

# %%
# Launch ComfyUI with WAN 2.1 Workflow
# You can provide your own workflow URL or use default
# !curl -sLo $scripts_dir/wan21_i2v.json https://raw.githubusercontent.com/sparkart/sdAIgen/main/workflows/wan21_i2v_480p.json 2>/dev/null
# %run $scripts_dir/launch.py -w $scripts_dir/wan21_i2v.json

# %% [markdown]
# ---
# # Utilities

# %%
# Run AutoCleaner.
# %run $scripts_dir/auto-cleaner.py
